# %% [markdown]
# <a href="https://colab.research.google.com/github/rituy-mahajan/LGM_DS/blob/main/task1_4LGM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **LGM VIRTUAL INTERNSHIP**

# %% [markdown]
# # **4)Image to Pencil Sketch with Python**:
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python. Reference:Watch Tutorial from here https://youtu.be/CBCfOTePVPo https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/
#
# 01
#
# ***BEGINNER LEVEL TASK***

# %% [markdown]
# Imported libraries

# %%
import os
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# Read image

# %%
img=cv2.imread('/content/image.png')

# %% [markdown]
# show/ print image

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=324x174 at 0x7FB76CEB9BD0>

# %% [markdown]
# image map as RGB

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis(False)
# Out:
# (-0.5, 323.5, 173.5, -0.5)

# %% [markdown]
# save image as temp.png

# %%
plt.savefig('temp.png')
plt.show()
plt.imshow(RGB_img)

# %% [markdown]
# map image into grey Scale

# %%
gray_scale_image=cv2.cvtColor(RGB_img,cv2.COLOR_BGR2GRAY) 
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=324x174 at 0x7FB76CCC3C10>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7FB76CDB2810>

# %% [markdown]
# blur image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=324x174 at 0x7FB76CC72310>

# %% [markdown]
# inverte the image

# %%
inverted_image = cv2.bitwise_not(gray_scale_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=324x174 at 0x7FB76CCA2E10>

# %% [markdown]
# map image as sketching by pencil

# %%
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch=pencil_sketch(gray_scale_image,img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=324x174 at 0x7FB76CE46990>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_scale_image,img_smoothing, scale=2048)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=324x174 at 0x7FB76CCA2FD0>
# -1
