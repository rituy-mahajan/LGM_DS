# %% [markdown]
# <a href="https://colab.research.google.com/github/rituy-mahajan/LGM_DS/blob/main/task1LGM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LGM VIRTUAL INTERNSHIP**

# %% [markdown]
# **Task 1: Iris Flowers Classification ML Project** :
#
#
#
#
#
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.

# %%
import numpy as np;
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import confusion_matrix

# %%
df=pd.read_csv("/content/iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [5 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['SepalWidthCm'].hist()

# %%
df['SepalLengthCm'].hist()

# %%
df['PetalWidthCm'].hist()

# %%
df['PetalLengthCm'].hist()

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  ...  PetalLengthCm  PetalWidthCm
# Id             1.000000       0.716676  ...       0.882747      0.899759
# SepalLengthCm  0.716676       1.000000  ...       0.871754      0.817954
# SepalWidthCm  -0.397729      -0.109369  ...      -0.420516     -0.356544
# PetalLengthCm  0.882747       0.871754  ...       1.000000      0.962757
# PetalWidthCm   0.899759       0.817954  ...       0.962757      1.000000
#
# [5 rows x 5 columns]

# %%
corr=df.corr()
fig,ax= plt.subplots(figsize=(5,4))
sns.heatmap(corr,annot=True, ax=ax, cmap='coolwarm')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
X= df.drop(columns=['Species'])
y=df['Species']

# %%
X[:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int64

# %%
import warnings 
warnings.filterwarnings('ignore')
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
import pydotplus

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Species')

# %%
sns.set(rc={'figure.figsize':(20,10)})
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3f87c8b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3f8699810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3f8662f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3f861c490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3f8650990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3f8605e90>]],
#       dtype=object)

# %%
sns.set(rc={'figure.figsize':(8,7)})
sns.boxplot(x='Species', y='SepalLengthCm',data=df)

# %%
sns.set(rc={'figure.figsize':(8,7)})
sns.boxplot(x='Species', y='PetalLengthCm',data=df)

# %%
sns.set(rc={'figure.figsize':(8,7)})
sns.boxplot(x='Species', y='SepalWidthCm',data=df)

# %%
sns.set(rc={'figure.figsize':(8,7)})
sns.boxplot(x='Species', y='PetalWidthCm',data=df)

# %%
colors = ['red', 'orange', 'blue']
species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.add_axes([0,0,1,1])
colors = ['red','blue','green']
sp = df['Species'].unique()
vc = df['Species'].value_counts()
ax.pie(vc, labels=sp, autopct='%1.2f%%', colors=colors)
plt.title('Percentage of Different Species')
plt.show()
